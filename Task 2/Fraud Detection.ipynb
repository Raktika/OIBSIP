# %%
#import libaries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import dataset
Creditcard_dataset = pd.read_csv('C:/Users/rakti/OneDrive/datasets/creditcard.csv')

# %%
Creditcard_dataset.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#To detect missing values
Creditcard_dataset.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
Creditcard_dataset.shape
# Out:
# (284807, 31)

# %%
Creditcard_dataset.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
Creditcard_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
Creditcard = Creditcard_dataset.groupby("Class").mean()
Creditcard
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Data Visualisation

# %%
sns.countplot(x='Class',data=Creditcard_dataset)
plt.title("0: Non-fraud 1: Fraud")
# Out:
# Text(0.5, 1.0, '0: Non-fraud 1: Fraud')

# %%
plt.figure(figsize=(20, 7))
sns.kdeplot(Creditcard_dataset[Creditcard_dataset['Class'] == 1]['Time'] ,label = 'Class=Fraud')
sns.kdeplot(Creditcard_dataset[Creditcard_dataset['Class'] == 0]['Time'], label = 'Class=Nonfraud')
plt.legend()
plt.title("KDE Plot for Time to detect faudable")
plt.show()
# Out:
# C:\Users\rakti\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\rakti\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Class', y='Amount', data=Creditcard_dataset, estimator='mean', palette='coolwarm')
plt.title('Average Amount Content by Class')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Class', y='Time', data=Creditcard_dataset, estimator='mean', palette='viridis')
plt.title('Average time by Class')
plt.show()
# Out:
# C:\Users\rakti\AppData\Local\Temp\ipykernel_21940\346545428.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x='Class', y='Time', data=Creditcard_dataset, estimator='mean', palette='viridis')
# C:\Users\rakti\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\rakti\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(Creditcard.T, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Mean features value for each class')
plt.show()

# %%
# identify dependent and independent variable
X = Creditcard_dataset.drop('Class', axis=1)
y = Creditcard_dataset.Class

# %%
X
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
# Initialize SMOTE with a random seed for reproducibility
smote = SMOTE(random_state=42)
# Apply SMOTE to the dataset
X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
X_resampled
# Out:
#                  Time        V1        V2        V3        V4        V5  \
# 0            0.000000 -1.359807 -0.072781  2.536347  1.378155 -0.338321
# 1            0.000000  1.191857  0.266151  0.166480  0.448154  0.060018
# 2            1.000000 -1.358354 -1.340163  1.773209  0.379780 -0.503198
# 3            1.000000 -0.966272 -0.185226  1.792993 -0.863291 -0.010309
# 4            2.000000 -1.158233  0.877737  1.548718  0.403034 -0.407193
# ...               ...       ...       ...       ...       ...       ...
# 568625  144838.659385 -6.379157  1.672637 -5.885670  2.068340 -0.668576
# 568626   65965.011763 -2.479028  0.958932 -1.782249  1.541783 -1.191990
# 568627   34592.129093 -1.799894  2.368957 -2.673997  1.705968 -1.355923
# 568628  129683.002907  0.255234  2.432041 -5.388252  3.793925 -0.230814
# 568629   91471.277869 -4.453646  3.210469 -5.294410  1.449911 -1.264653
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
y_resampled
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 568625    1
# 568626    1
# 568627    1
# 568628    1
# 568629    1
# Name: Class, Length: 568630, dtype: int64

# %%
sns.countplot(x=y_resampled,data=Creditcard_dataset)
plt.title("0: Non-fraud 1: Fraud")
# Out:
# Text(0.5, 1.0, '0: Non-fraud 1: Fraud')

# %%
#Feature Scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_resampled_scaled = scaler.fit_transform(X_resampled)

# %%
X_resampled_scaled
# Out:
# array([[-1.8249305 ,  0.20447492, -0.54748253, ...,  0.05497586,
#         -0.14982747,  0.24549597],
#        [-1.8249305 ,  0.67297588, -0.45417255, ..., -0.09485495,
#         -0.06419549, -0.42130253],
#        [-1.82490971,  0.20474171, -0.89640034, ..., -0.14359591,
#         -0.24245216,  1.28492649],
#        ...,
#        [-1.10608516,  0.12367227,  0.1247426 , ..., -0.21277423,
#         -1.37812378,  0.03159593],
#        [ 0.86996062,  0.50100631,  0.14211006, ...,  0.24622922,
#         -0.31725696, -0.1687203 ],
#        [ 0.0758979 , -0.36357256,  0.35641598, ..., -0.4672204 ,
#          2.33747419,  0.21941376]])

# %%
#Train Variables
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_resampled_scaled, y_resampled, test_size=0.3, random_state=0)

# %%
#Logit Regression
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# C:\Users\rakti\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=0)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[84425   747]
#  [ 2626 82791]]
# 0.9802273300154172

# %%
#Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
classifier_1 = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier_1.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
Y_pred = classifier_1.predict(X_test)
cm_1 = confusion_matrix(y_test, y_pred)
print(cm_1)
accuracy_score(y_test, y_pred)
# Out:
# [[84425   747]
#  [ 2626 82791]]
# 0.9802273300154172

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
classifier_2 = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier_2.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier_2.predict(X_test)
cm_2 = confusion_matrix(y_test, y_pred)
print(cm_2)
accuracy_score(y_test, y_pred)
# Out:
# [[85147    25]
#  [    0 85417]]
# 0.9998534489328151

# %%
#Random Forest is appropriate model for fraud detectiion
