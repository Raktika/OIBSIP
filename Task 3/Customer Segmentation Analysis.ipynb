# %%
#import libaries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import dataset
Customer_dataset = pd.read_csv('C:/Users/rakti/OneDrive/datasets/ifood_df.csv')

# %%
Customer_dataset.head()
# Out:
#     Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  58138.0        0         0       58       635         88              546
# 1  46344.0        1         1       38        11          1                6
# 2  71613.0        0         0       26       426         49              127
# 3  26646.0        1         0       26        11          4               20
# 4  58293.0        1         0       94       173         43              118
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  marital_Together  \
# 0              172                88            88  ...                 0
# 1                2                 1             6  ...                 0
# 2              111                21            42  ...                 1
# 3               10                 3             5  ...                 1
# 4               46                27            15  ...                 0
#
# ...

# %%
Customer_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2205 entries, 0 to 2204
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Income                2205 non-null   float64
#  1   Kidhome               2205 non-null   int64
#  2   Teenhome              2205 non-null   int64
#  3   Recency               2205 non-null   int64
#  4   MntWines              2205 non-null   int64
#  5   MntFruits             2205 non-null   int64
#  6   MntMeatProducts       2205 non-null   int64
#  7   MntFishProducts       2205 non-null   int64
#  8   MntSweetProducts      2205 non-null   int64
#  9   MntGoldProds          2205 non-null   int64
#  10  NumDealsPurchases     2205 non-null   int64
#  11  NumWebPurchases       2205 non-null   int64
#  12  NumCatalogPurchases   2205 non-null   int64
#  13  NumStorePurchases     2205 non-null   int64
#  14  NumWebVisitsMonth     2205 non-null   int64
# ...

# %%
Customer_dataset.isnull().sum()
# Out:
# Income                  0
# Kidhome                 0
# Teenhome                0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# Age                     0
# Customer_Days           0
# marital_Divorced        0
# marital_Married         0
# marital_Single          0
# marital_Together        0
# marital_Widow           0
# education_2n Cycle      0
# education_Basic         0
# education_Graduation    0
# education_Master        0
# ...

# %%
Customer_dataset.shape
# Out:
# (2205, 39)

# %%
Customer_dataset.describe()
# Out:
#               Income      Kidhome     Teenhome      Recency     MntWines  \
# count    2205.000000  2205.000000  2205.000000  2205.000000  2205.000000
# mean    51622.094785     0.442177     0.506576    49.009070   306.164626
# std     20713.063826     0.537132     0.544380    28.932111   337.493839
# min      1730.000000     0.000000     0.000000     0.000000     0.000000
# 25%     35196.000000     0.000000     0.000000    24.000000    24.000000
# 50%     51287.000000     0.000000     0.000000    49.000000   178.000000
# 75%     68281.000000     1.000000     1.000000    74.000000   507.000000
# max    113734.000000     2.000000     2.000000    99.000000  1493.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2205.000000      2205.000000      2205.000000       2205.000000
# mean     26.403175       165.312018        37.756463         27.128345
# std      39.784484       217.784507        54.824635         41.130468
# ...

# %%
Customer_dataset.columns
# Out:
# Index(['Income', 'Kidhome', 'Teenhome', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response',
#        'Age', 'Customer_Days', 'marital_Divorced', 'marital_Married',
#        'marital_Single', 'marital_Together', 'marital_Widow',
#        'education_2n Cycle', 'education_Basic', 'education_Graduation',
#        'education_Master', 'education_PhD', 'MntTotal', 'MntRegularProds',
#        'AcceptedCmpOverall'],
#       dtype='object')

# %%
Customer_dataset.Response
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2200    0
# 2201    0
# 2202    0
# 2203    0
# 2204    1
# Name: Response, Length: 2205, dtype: int64

# %%
Customer_dataset = Customer_dataset.dropna()

# %%
Customer_dataset
# Out:
#        Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0     58138.0        0         0       58       635         88
# 1     46344.0        1         1       38        11          1
# 2     71613.0        0         0       26       426         49
# 3     26646.0        1         0       26        11          4
# 4     58293.0        1         0       94       173         43
# ...       ...      ...       ...      ...       ...        ...
# 2200  61223.0        0         1       46       709         43
# 2201  64014.0        2         1       56       406          0
# 2202  56981.0        0         0       91       908         48
# 2203  69245.0        0         1        8       428         30
# 2204  52869.0        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 0                 546              172                88            88  ...
# ...

# %%
Customer_dataset.drop(columns=['Z_CostContact','Z_Revenue'],inplace=True)

# %%
sns.boxplot(Customer_dataset['MntTotal'])
# Out:
# <Axes: >

# %%
# Calculate Q1 and Q3
Q1 = Customer_dataset['MntTotal'].quantile(0.25)
Q3 = Customer_dataset['MntTotal'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Detect outliers
outliers = Customer_dataset[( Customer_dataset['MntTotal'] < lower_bound) | ( Customer_dataset['MntTotal'] > upper_bound)]

# Print outliers
print(outliers)
# Out:
#        Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 1159  90638.0        0         0       29      1156        120
# 1467  87679.0        0         0       62      1259        172
# 1547  90638.0        0         0       29      1156        120
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 1159              915               94               144            96  ...
# 1467              815               97               148            33  ...
# 1547              915               94               144            96  ...
#
#       marital_Together  marital_Widow  education_2n Cycle  education_Basic  \
# 1159                 0              0                   0                0
# 1467                 1              0                   0                0
# 1547                 0              0                   0                0
#
#       education_Graduation  education_Master  education_PhD  MntTotal  \
# ...

# %%
# Define lower and upper percentile limits
lower_cap = Customer_dataset['MntTotal'].quantile(0.01)
upper_cap = Customer_dataset['MntTotal'].quantile(0.99)

# Cap outliers
Customer_dataset['MntTotal'] = np.where(Customer_dataset['MntTotal'] < lower_cap, lower_cap, Customer_dataset['MntTotal'])
Customer_dataset['MntTotal'] = np.where(Customer_dataset['MntTotal'] > upper_cap, upper_cap, Customer_dataset['MntTotal'])

# %% [markdown]
# Data Visualisation

# %%
sns.distplot(Customer_dataset.Income, kde = True)
# Out:
# C:\Users\rakti\AppData\Local\Temp\ipykernel_19824\3158127494.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Customer_dataset.Income, kde = True)
# C:\Users\rakti\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Income', ylabel='Density'>

# %%
sns.distplot(Customer_dataset.Age)
# Out:
# C:\Users\rakti\AppData\Local\Temp\ipykernel_19824\3180343128.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Customer_dataset.Age)
# C:\Users\rakti\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Density'>

# %%
def get_marital_status(row):
    if row['marital_Divorced'] == 1:
        return 'Divorced'
    elif row['marital_Married'] == 1:
        return 'Married'
    elif row['marital_Single'] == 1:
        return 'Single'
    elif row['marital_Together'] == 1:
        return 'Together'
    elif row['marital_Widow'] == 1:
        return 'Widow'
    else:
        return 'Unknown'
Customer_dataset['Marital Status'] = Customer_dataset.apply(get_marital_status, axis=1)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Marital Status', y='MntTotal', data= Customer_dataset, estimator='mean', palette='coolwarm')
plt.title('Average MntTotal Content by different Marital Status')
plt.show()

# %%
def get_relationship(row):
    if row['marital_Married'] ==1:
        return 1
    elif row['marital_Together'] == 1:
        return 1
    else:
        return 0
Customer_dataset['In_relationship'] = Customer_dataset.apply(get_relationship, axis=1)

# %%
Customer_dataset
# Out:
#        Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0     58138.0        0         0       58       635         88
# 1     46344.0        1         1       38        11          1
# 2     71613.0        0         0       26       426         49
# 3     26646.0        1         0       26        11          4
# 4     58293.0        1         0       94       173         43
# ...       ...      ...       ...      ...       ...        ...
# 2200  61223.0        0         1       46       709         43
# 2201  64014.0        2         1       56       406          0
# 2202  56981.0        0         0       91       908         48
# 2203  69245.0        0         1        8       428         30
# 2204  52869.0        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 0                 546              172                88            88  ...
# ...

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='In_relationship', y='Income', data= Customer_dataset, estimator='mean', palette='coolwarm')
plt.title('Average Income Content by different Marital Status')
plt.show()

# %%
X = Customer_dataset[['Income','MntTotal','In_relationship']]

# %%
X
# Out:
#        Income  MntTotal  In_relationship
# 0     58138.0    1529.0                0
# 1     46344.0      21.0                0
# 2     71613.0     734.0                1
# 3     26646.0      48.0                1
# 4     58293.0     407.0                1
# ...       ...       ...              ...
# 2200  61223.0    1094.0                1
# 2201  64014.0     436.0                1
# 2202  56981.0    1217.0                0
# 2203  69245.0     782.0                1
# 2204  52869.0     151.0                1
#
# [2205 rows x 3 columns]

# %%
#Clustering
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# C:\Users\rakti\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rakti\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# C:\Users\rakti\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)
# Out:
# C:\Users\rakti\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rakti\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(

# %%
#Taking 5 clusters
km1=KMeans(n_clusters=5)
#Fitting the input data
km1.fit(X)
#predicting the labels of the input data
y=km1.predict(X)
#adding the labels to a column named label
Customer_dataset["label"] = y
# Out:
# C:\Users\rakti\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rakti\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(

# %%
Customer_dataset.head()
# Out:
#     Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  58138.0        0         0       58       635         88              546
# 1  46344.0        1         1       38        11          1                6
# 2  71613.0        0         0       26       426         49              127
# 3  26646.0        1         0       26        11          4               20
# 4  58293.0        1         0       94       173         43              118
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  education_Basic  \
# 0              172                88            88  ...                0
# 1                2                 1             6  ...                0
# 2              111                21            42  ...                0
# 3               10                 3             5  ...                0
# 4               46                27            15  ...                0
#
# ...

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x = 'Income',y = 'MntTotal',hue="label",  
                 palette=['green','orange','brown','dodgerblue','red'], legend='full',data = Customer_dataset  ,s = 60 )
plt.xlabel('Income')
plt.ylabel('MntTotal') 
plt.title('MntTotal vs Income')
plt.show()

# %%
#3D Plot as we did the clustering on the basis of 3 input features
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(Customer_dataset.In_relationship[Customer_dataset.label == 0], Customer_dataset["Income"][Customer_dataset.label == 0], Customer_dataset["MntTotal"][Customer_dataset.label == 0], c='purple', s=60)
ax.scatter(Customer_dataset.In_relationship[Customer_dataset.label == 1], Customer_dataset["Income"][Customer_dataset.label == 1], Customer_dataset["MntTotal"][Customer_dataset.label == 1], c='red', s=60)
ax.scatter(Customer_dataset.In_relationship[Customer_dataset.label == 2], Customer_dataset["Income"][Customer_dataset.label == 2], Customer_dataset["MntTotal"][Customer_dataset.label == 2], c='blue', s=60)
ax.scatter(Customer_dataset.In_relationship[Customer_dataset.label == 3], Customer_dataset["Income"][Customer_dataset.label == 3], Customer_dataset["MntTotal"][Customer_dataset.label == 3], c='green', s=60)
ax.scatter(Customer_dataset.In_relationship[Customer_dataset.label == 4], Customer_dataset["Income"][Customer_dataset.label == 4], Customer_dataset["MntTotal"][Customer_dataset.label == 4], c='yellow', s=60)
ax.view_init(35, 185)
plt.xlabel("In_relationship")
plt.ylabel("Income")
ax.set_zlabel('MntTotal')
plt.show()
